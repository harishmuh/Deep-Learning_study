# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmuh/Deep-Learning_study/blob/main/mlp_tensorflow_iris_flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Multi Layer Perceptron with TensorFlow - Iris flower Classififcation**
#
# ---

# %% [markdown]
# ![iris](https://upload.wikimedia.org/wikipedia/commons/a/a7/Irissetosa1.jpg)

# %% [markdown]
# ### **Context**
#
# In this study, we will construct a Multi-Layer Perceptron (MLP) model using TensorFlow/Keras to classify iris flowers based on their physical features.
#
#
# This MLP is a type of neural network with an architecture consisting of input, hidden, and output layers of interconnected neurons. This network is capable of learning complex patterns and performing tasks such as classification and regression by adjusting its parameters through training.

# %% [markdown]
# ### **About dataset**
#
# **Dataset Characteristics:**
#
# Total samples: 150
#
# Number of features: 4
#
# Number of classes: 3
#
# Type: Supervised multi-class classification
#
# Features:
#
# * Sepal length (cm)
#
# * Sepal width (cm)
#
# * Petal length (cm)
#
# * Petal width (cm)
#
# Target Classes:
#
# * 0 → Setosa
#
# * 1 → Versicolor
#
# * 2 → Virginica

# %%
# Importing libraries
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

import warnings
warnings.filterwarnings('ignore')

# style
plt.style.use('ggplot')

# %% [markdown]
# **Loading dataset**

# %%
# Loading iris dataset
uci_datasets = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
df = pd.read_csv(uci_datasets, header=None)
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
# data dimension
df.shape
# Out:
# (150, 5)

# %%
# Rename columns
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# **Defining features and target**

# %%
# Features and targets
X = df.drop('class', axis=1)
y = df['class']

# %%
# Replacing values using LabelEncoder
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y1 = le.fit_transform(y)
y = pd.get_dummies(y1).values

# %%
# Check y
y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %% [markdown]
# **Data splitting**
#
# We use 80% of data as training set and 20% of data as testing set.

# %%
# Data splitting
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Check shape
print('Data Training: ')
print(X_train.shape)
print(y_train.shape)
print('Data Testing: ')
print(X_test.shape)
print(y_test.shape)
# Out:
# Data Training:
# (120, 4)
# (120, 3)
# Data Testing:
# (30, 4)
# (30, 3)

# %% [markdown]
# **Model building**
#
# We will build the MLP model with input layer, 2 hidden layers, and output layer.

# %%
# MLP model

modelMLP = tf.keras.Sequential()

# Input layer --> input size 4 because of 4 features
modelMLP.add(tf.keras.layers.Input(shape=(4,)))

# Hidden layer 1: neuron = 4
modelMLP.add(tf.keras.layers.Dense(4, activation='relu'))

# Hidden layer 2: neuron = 4
modelMLP.add(tf.keras.layers.Dense(4, activation='relu'))

# Output layer: neuron = 3 due to 3 labels
modelMLP.add(tf.keras.layers.Dense(3, activation='softmax'))

# %% [markdown]
# **Compiling model**

# %%
# compiling
# Use Adam as optimizer, learning rate 0.01
# Minimize loss categorical crossentropy
modelMLP.compile(Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])
modelMLP.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            15 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55 (220.00 B)
#  Trainable params: 55 (220.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# So, we will build MLP and train 55 parameters.

# %%
# Saving model architecture/workflow
plot_model(modelMLP, 'model.png', show_shapes=True)

# %% [markdown]
# **Model training**
#
# We will train the model for 100 epochs and use 20% of data for data validation. We can use batch_size=16, means that the training data (X_train and y_train) will be divided into batches of 16 samples, and the model's weights will be updated after processing each batch.

# %%
# Training
historyMLP = modelMLP.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Epoch --> number of training
# Validation_split = 0.2 --> 20% of data can be used for data validation
# batch_size=16 --> training data (X_train and y_train) divided into batches of 16 samples
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.3542 - loss: 0.9658 - val_accuracy: 0.6250 - val_loss: 0.9074
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5117 - loss: 0.9206 - val_accuracy: 0.3333 - val_loss: 0.9097
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3919 - loss: 0.8855 - val_accuracy: 0.4167 - val_loss: 0.8921
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6589 - loss: 0.8416 - val_accuracy: 0.5417 - val_loss: 0.8706
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.7161 - loss: 0.7940 - val_accuracy: 0.5417 - val_loss: 0.8396
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7292 - loss: 0.7407 - val_accuracy: 0.5833 - val_loss: 0.7838
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7292 - loss: 0.6737 - val_accuracy: 0.7500 - val_loss: 0.6993
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8424 - loss: 0.6320 - val_accuracy: 0.8333 - val_loss: 0.6514
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9010 - loss: 0.5808 - val_accuracy: 0.7500 - val_loss: 0.6235
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8320 - loss: 0.5284 - val_accuracy: 0.5833 - val_loss: 0.6273
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7969 - loss: 0.4635 - val_accuracy: 0.5833 - val_loss: 0.6186
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.4729 - val_accuracy: 0.6667 - val_loss: 0.5527
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8346 - loss: 0.4554 - val_accuracy: 0.8333 - val_loss: 0.5102
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9010 - loss: 0.3847 - val_accuracy: 0.8750 - val_loss: 0.4867
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8672 - loss: 0.3924 - val_accuracy: 0.8333 - val_loss: 0.4720
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8672 - loss: 0.3559 - val_accuracy: 0.7917 - val_loss: 0.4696
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8867 - loss: 0.3255 - val_accuracy: 0.8333 - val_loss: 0.4458
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9076 - loss: 0.2975 - val_accuracy: 0.8750 - val_loss: 0.4162
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9310 - loss: 0.3250 - val_accuracy: 0.9167 - val_loss: 0.3707
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9609 - loss: 0.3064 - val_accuracy: 0.8750 - val_loss: 0.3665
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9688 - loss: 0.3086 - val_accuracy: 0.8750 - val_loss: 0.3665
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9062 - loss: 0.2822 - val_accuracy: 0.8750 - val_loss: 0.3667
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9245 - loss: 0.2548 - val_accuracy: 0.8750 - val_loss: 0.3302
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9570 - loss: 0.2536 - val_accuracy: 0.9167 - val_loss: 0.2917
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9857 - loss: 0.2415 - val_accuracy: 0.9167 - val_loss: 0.2953
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9609 - loss: 0.2366 - val_accuracy: 0.8750 - val_loss: 0.3162
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9466 - loss: 0.2265 - val_accuracy: 0.8750 - val_loss: 0.2931
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9844 - loss: 0.2108 - val_accuracy: 0.9167 - val_loss: 0.2512
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9779 - loss: 0.2273 - val_accuracy: 0.9167 - val_loss: 0.2309
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9740 - loss: 0.2184 - val_accuracy: 0.8750 - val_loss: 0.2538
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9740 - loss: 0.1866 - val_accuracy: 0.8750 - val_loss: 0.2955
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9635 - loss: 0.1931 - val_accuracy: 0.9167 - val_loss: 0.2193
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9896 - loss: 0.1983 - val_accuracy: 0.9583 - val_loss: 0.1908
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9609 - loss: 0.2006 - val_accuracy: 0.9167 - val_loss: 0.2111
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9779 - loss: 0.1870 - val_accuracy: 0.8750 - val_loss: 0.2419
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9661 - loss: 0.1879 - val_accuracy: 0.9167 - val_loss: 0.2045
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9740 - loss: 0.1902 - val_accuracy: 0.9167 - val_loss: 0.1756
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9661 - loss: 0.1847 - val_accuracy: 0.8750 - val_loss: 0.2120
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9779 - loss: 0.1508 - val_accuracy: 0.9167 - val_loss: 0.2057
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9779 - loss: 0.1554 - val_accuracy: 0.9167 - val_loss: 0.1777
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9661 - loss: 0.1647 - val_accuracy: 0.9167 - val_loss: 0.1659
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9779 - loss: 0.1471 - val_accuracy: 0.9167 - val_loss: 0.1978
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9896 - loss: 0.1341 - val_accuracy: 0.9167 - val_loss: 0.1671
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9857 - loss: 0.1212 - val_accuracy: 0.9167 - val_loss: 0.1569
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9857 - loss: 0.1210 - val_accuracy: 0.9167 - val_loss: 0.1583
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9661 - loss: 0.1498 - val_accuracy: 0.9167 - val_loss: 0.1477
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9779 - loss: 0.1434 - val_accuracy: 0.9167 - val_loss: 0.1791
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9740 - loss: 0.1407 - val_accuracy: 0.9167 - val_loss: 0.1494
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9661 - loss: 0.1392 - val_accuracy: 0.9167 - val_loss: 0.1454
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9818 - loss: 0.1121 - val_accuracy: 0.9167 - val_loss: 0.1499
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9740 - loss: 0.1161 - val_accuracy: 0.9167 - val_loss: 0.1540
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9740 - loss: 0.1148 - val_accuracy: 0.9167 - val_loss: 0.1502
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9779 - loss: 0.0982 - val_accuracy: 0.9167 - val_loss: 0.1402
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9661 - loss: 0.1270 - val_accuracy: 0.9167 - val_loss: 0.1297
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9661 - loss: 0.1296 - val_accuracy: 0.9167 - val_loss: 0.1547
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9857 - loss: 0.0879 - val_accuracy: 0.9167 - val_loss: 0.1566
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9779 - loss: 0.1063 - val_accuracy: 0.9167 - val_loss: 0.1203
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9740 - loss: 0.0988 - val_accuracy: 0.9167 - val_loss: 0.1252
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9857 - loss: 0.0975 - val_accuracy: 0.9167 - val_loss: 0.1664
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9740 - loss: 0.1176 - val_accuracy: 0.9167 - val_loss: 0.1291
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9857 - loss: 0.0866 - val_accuracy: 0.9167 - val_loss: 0.1214
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9779 - loss: 0.0859 - val_accuracy: 0.9167 - val_loss: 0.1212
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9661 - loss: 0.1050 - val_accuracy: 0.9167 - val_loss: 0.1300
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9857 - loss: 0.0883 - val_accuracy: 0.9167 - val_loss: 0.1457
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9818 - loss: 0.0880 - val_accuracy: 0.9167 - val_loss: 0.1148
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9831 - loss: 0.1134 - val_accuracy: 0.9167 - val_loss: 0.1068
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9740 - loss: 0.1069 - val_accuracy: 0.9167 - val_loss: 0.1319
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9857 - loss: 0.0718 - val_accuracy: 0.9167 - val_loss: 0.1503
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9779 - loss: 0.0846 - val_accuracy: 0.9167 - val_loss: 0.1180
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9909 - loss: 0.0755 - val_accuracy: 0.9583 - val_loss: 0.0958
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9948 - loss: 0.0787 - val_accuracy: 0.9167 - val_loss: 0.1181
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9661 - loss: 0.1045 - val_accuracy: 0.9167 - val_loss: 0.1402
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9740 - loss: 0.1051 - val_accuracy: 0.9167 - val_loss: 0.1274
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9661 - loss: 0.1148 - val_accuracy: 0.9167 - val_loss: 0.1213
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9909 - loss: 0.0785 - val_accuracy: 0.9167 - val_loss: 0.1114
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9831 - loss: 0.0995 - val_accuracy: 0.9167 - val_loss: 0.1135
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9779 - loss: 0.0978 - val_accuracy: 0.9167 - val_loss: 0.1345
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9896 - loss: 0.0778 - val_accuracy: 0.9167 - val_loss: 0.1540
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9909 - loss: 0.0747 - val_accuracy: 0.9583 - val_loss: 0.0844
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9948 - loss: 0.0727 - val_accuracy: 0.9167 - val_loss: 0.1053
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9818 - loss: 0.0709 - val_accuracy: 0.9167 - val_loss: 0.1378
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9740 - loss: 0.0842 - val_accuracy: 0.9167 - val_loss: 0.1274
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9831 - loss: 0.0902 - val_accuracy: 0.9167 - val_loss: 0.1046
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9831 - loss: 0.0926 - val_accuracy: 0.9167 - val_loss: 0.1011
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9896 - loss: 0.0811 - val_accuracy: 0.9167 - val_loss: 0.1675
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9857 - loss: 0.0633 - val_accuracy: 0.9167 - val_loss: 0.1072
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9948 - loss: 0.0676 - val_accuracy: 0.9583 - val_loss: 0.0742
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9831 - loss: 0.0974 - val_accuracy: 0.9167 - val_loss: 0.1001
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9740 - loss: 0.0916 - val_accuracy: 0.9167 - val_loss: 0.1741
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9740 - loss: 0.0786 - val_accuracy: 0.9167 - val_loss: 0.1336
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9740 - loss: 0.0866 - val_accuracy: 1.0000 - val_loss: 0.0666
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9948 - loss: 0.0730 - val_accuracy: 0.9167 - val_loss: 0.1257
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9740 - loss: 0.0796 - val_accuracy: 0.9167 - val_loss: 0.1248
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9896 - loss: 0.0595 - val_accuracy: 0.9167 - val_loss: 0.1280
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9688 - loss: 0.0808 - val_accuracy: 0.9583 - val_loss: 0.0722
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9948 - loss: 0.0866 - val_accuracy: 0.9167 - val_loss: 0.1591
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9844 - loss: 0.0580 - val_accuracy: 0.9167 - val_loss: 0.1530
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9831 - loss: 0.0935 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9805 - loss: 0.0692 - val_accuracy: 0.9583 - val_loss: 0.0793
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9896 - loss: 0.0609 - val_accuracy: 0.9167 - val_loss: 0.1696

# %% [markdown]
# **Model Accuracy**

# %%
# Plotting Accuracy
plt.plot(historyMLP.history['accuracy'], label='Train accuracy')
plt.plot(historyMLP.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()

# %%
# Plotting loss
plt.plot(historyMLP.history['loss'], label='Train loss')
plt.plot(historyMLP.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# **Predicting to test set**

# %%
# Predict
y_pred_MLP = modelMLP.predict(X_test)
y_pred_MLP
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# array([[3.0121718e-09, 2.0148347e-03, 9.9798506e-01],
#        [7.4300903e-04, 9.9370527e-01, 5.5517401e-03],
#        [9.9873048e-01, 1.2695374e-03, 9.1372925e-15],
#        [2.0573554e-10, 1.3166443e-03, 9.9868333e-01],
#        [9.9770665e-01, 2.2932857e-03, 1.6530438e-13],
#        [2.3803715e-10, 8.9047401e-04, 9.9910951e-01],
#        [9.9782389e-01, 2.1761120e-03, 1.2785423e-13],
#        [1.4012204e-04, 9.6362078e-01, 3.6239114e-02],
#        [6.5947723e-05, 9.3751007e-01, 6.2423985e-02],
#        [1.2872304e-03, 9.9520934e-01, 3.5033822e-03],
#        [9.3272368e-09, 4.5739724e-03, 9.9542600e-01],
#        [3.3043645e-04, 9.7575450e-01, 2.3915075e-02],
#        [1.2314659e-04, 8.6329216e-01, 1.3658461e-01],
#        [8.8603170e-05, 9.1009170e-01, 8.9819722e-02],
#        [7.4642703e-05, 7.4152303e-01, 2.5840232e-01],
#        [9.9760479e-01, 2.3951533e-03, 2.0452761e-13],
#        [1.1910223e-04, 8.0082953e-01, 1.9905135e-01],
#        [1.5483942e-04, 7.1927410e-01, 2.8057098e-01],
#        [9.9716753e-01, 2.8324353e-03, 4.6514756e-13],
#        [9.9851000e-01, 1.4899657e-03, 2.0006629e-14],
#        [2.3299380e-08, 3.9806855e-03, 9.9601924e-01],
#        [9.0930051e-05, 5.5319488e-01, 4.4671407e-01],
#        [9.9568212e-01, 4.3178825e-03, 2.4207728e-12],
#        [9.9581718e-01, 4.1827345e-03, 3.1456283e-12],
#        [2.9649714e-06, 1.6335885e-01, 8.3663821e-01],
#        [9.9727005e-01, 2.7299477e-03, 3.8828814e-13],
#        [9.9706537e-01, 2.9346799e-03, 5.5343973e-13],
#        [5.7085161e-04, 9.8775941e-01, 1.1669692e-02],
#        [8.1445109e-03, 9.8975909e-01, 2.0963962e-03],
#        [9.9727422e-01, 2.7258343e-03, 3.8542902e-13]], dtype=float32)

# %%
# Class of the prediction
y_test_class = np.argmax(y_test, axis=1)
y_test_class
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0])

# %%
# Convert predicted probabilities to class labels
y_pred_MLP_class = np.argmax(y_pred_MLP, axis=1)

# %%
# Accuracy score on test data
from sklearn.metrics import accuracy_score

print('Accuracy score on the test data:')
accuracy_score(y_test_class, y_pred_MLP_class)
# Out:
# Accuracy score on the test data:
# 1.0

# %%
# Confusion matrix test data
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm_test = confusion_matrix(y_test_class, y_pred_MLP_class)
sns.heatmap(cm_test, annot=True, fmt='d')
plt.title('Confusion matrix on the test data')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
plt.show()
