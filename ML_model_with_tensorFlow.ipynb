# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmuh/Deep-Learning_study/blob/main/ML_model_with_tensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Creating Machine Learning Model with tensorFlow**
# ---

# %% [markdown]
# **What is the different between traditional programming and machine learning?**
#
# **Traditional programming**
#
# In traditional programming, When it comes to building apps, we need to hardcode all of rules and the program will act based on the given data to provide the answer.

# %% [markdown]
# ![image](https://developers.google.com/static/codelabs/tensorflow-1-helloworld/img/c72f871306134e45_1440.png)

# %% [markdown]
# **Machine learning**
#
# In machine learning, instead of defining all rules and expressing them in programming languange, we provide the answers (typically called *labels* or *targets*)

# %% [markdown]
# ![image](https://developers.google.com/static/codelabs/tensorflow-1-helloworld/img/9b85a337ee816e1b_1440.png)

# %% [markdown]
# **Creating Machine learning model with tensorFlow**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# How you define the relationship between variables above?
#
# As you look at them, you might notice that the value of X is increasing by 1 as you read left to right and the corresponding value of Y is increasing by 3. You probably think that Y equals 3X plus or minus something. Then, you'd probably look at the 0 on X and see that Y is 1, and you'd come up with the relationship as `Y=3X+1`

# %% [markdown]
# Now we will use TensorFlow library and calling it `tf`. Next, import a library called `numpy`, which represents our data as lists easily and quickly.
#
# We will also use `keras` as framework for defining a neural network as a set of sequential layers.

# %% [markdown]
# **Importing libraries**

# %%
# Importing libraries
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# **Define and compile the neural network**

# %% [markdown]
# Next, create the simplest possible neural network.
# * It has one layer
# * The layer has one neuron
# * The input shape to it is only one value.

# %%
# Defining the neural network
model = tf.keras.Sequential(
    [keras.layers.Dense(units=1, # One neuron
                        input_shape=[1])]) # One value of input shape
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Next, write the code to compile your neural network. When you do so, you need to specify two functions—a loss and an optimizer.

# %% [markdown]
# In this example, we know that the relationship between the numbers is Y=3X+1. However, When the computer is trying to learn that, it makes a guess, maybe Y=10X+10.
#
# `The loss function` measures the guessed answers against the known correct answers and measures how well or badly it did.

# %% [markdown]
# Next, the model uses the `optimizer` function to make another guess. Based on the loss function's result, it tries to minimize the loss. At this point, maybe it will come up with something like Y=5X+5. While that's still pretty bad, it's closer to the correct result (the loss is lower).

# %% [markdown]
# The model repeats that for the number of epochs, which you'll see shortly.
#
# First, here's how to tell it to use `mean_squared_error` for the loss and `stochastic gradient descent` (sgd) for the optimizer. You don't need to understand the math for those yet, but you can see that they work!
#
# Over time, we'll learn the different and appropriate loss and optimizer functions for different scenarios.

# %%
# Compiling model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# **Loading data**
#
# Next, feed some data. In this case, we take the six X and six Y variables from earlier. We can see that the relationship between those is that Y=3X+1, so where X is -1, Y is -2.
#
# A python library called NumPy provides lots of array type data structures to do this. Specify the values as an array in NumPy with np.array[].

# %%
# Loading data
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %% [markdown]
# **Train the neural network**
#
# The process of training the neural network, where it learns the relationship between the X's and Y's, is in the model.fit call. That's where it will go through the loop before making a guess, measuring how good or bad it is (the loss), or using the optimizer to make another guess. It will do that for the number of epochs that we specify. When we run that code, we'll see the loss will be printed out for each epoch.

# %%
# Model training
model.fit(xs, ys, epochs=50)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 4.4489e-08
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.3580e-08
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.2680e-08
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 4.1789e-08
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 4.0933e-08
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4.0085e-08
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.9246e-08
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.8416e-08
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 3.7637e-08
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.6893e-08
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 3.6112e-08
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 3.5385e-08
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 3.4598e-08
# Epoch 14/50
# ...

# %% [markdown]
# We can see that for the first few epochs, the loss value is quite large, but eventually it's getting smaller with each step. As the training progresses, the loss soon gets very small.

# %% [markdown]
# **Making Prediction**

# %% [markdown]
# we have a model that has been trained to learn the relationship between X and Y. we can use the model.predict method to have it figure out the Y for a previously unknown X. For example, if X is 10, what do we think Y will be? Take a guess before we run the following code:

# %%
print(model.predict(np.array([[10.0]])))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# [[30.999628]]

# %% [markdown]
# We might have thought 31, but it ended up being a little over. Why do we think that is?
#
# Neural networks deal with probabilities, so it calculated that there is a very high probability that the relationship between X and Y is Y=3X+1, but it can't know for sure with only six data points. The result is very close to 31, but not necessarily 31.

# %% [markdown]
# Thanks for following this tutorial!

# %% [markdown]
# **Reference**:
# * developers.google.com
